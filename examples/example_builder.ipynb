# %%
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from arborenum import ArborEnum

df = pd.read_csv("bike_processed.csv").sample(
    frac=1.0,
    replace=True,
    random_state=0,
).reset_index(drop=True)

y = df.pop("label").to_numpy(dtype=np.int32)
X = df

model = ArborEnum()

start = time.perf_counter()

model.fit(
    X,
    y,
    proxy_mode="hybrid",
    lambda_reg=0.005,
    depth_budget=7,
    rashomon_mult=0.03,
    lookahead_k=1,
    max_number_thresholds_per_feature=None,
    key_mode="hash",
)

model.save_builder_html("bike_builder.html")
# Out:
# Best objective: 2770 (0.159388)
# Objective bound: 2853
# Minimum objective: 2770
# Cache sizes - Greedy: 13035473, Lickety: 390113, Trie: 8225, Trie cache: ON
# PosixPath('bike_builder.html')
